# %% [markdown]
# <a href="https://www.scinbre.org/learning/bioinformatics-workshops/2024-summer-workshops"><img src="https://i.ibb.co/N6W5kPM/inbre-header.png" alt="inbre-header" border="0"></a>
#
#
# ### Machine Learning in Python
# ### June 3rd, 2024

# %% [markdown]
# # First hour - Introduction to Cloud Computing

# %% [markdown]
# ### Cloud Computing
#
# *   What is Cloud Computing?
# *   Why Cloud Computing?

# %% [markdown]
# **Cloud Computing like Baking:**
#
# Imagine normal coding like this: Coming up with and writing down a recipe is like writing the code. The baking part is like running the code on your computer. And the final baked product is like the output/result of the code.
#
# Cloud Computing: You write the code/recipe, then send it off to be baked by someone else. They come back with the final baked good. In our case, we send off our code, Google runs it, and the code output is sent back to you.
#
# **So what's the advantage?**
#
# Let's say we want to try a new recipe that requires a specific type of oven. We don't have to worry about buying and installing a whole new oven just to try it one time.
#
# Or, what if we had family coming to town and needed to make five times as many cakes as normal, but just once? Since our outsourced baker has many ovens, we can just pay the additional cost of using a few more ovens rather than buying a bunch of new ovens and having to install them all.

# %% [markdown]
# **NIH officials will present on NIH Cloud Computing.**

# %% [markdown]
# ### Options for the course
#
# 1. You can use [Google Colab](https://colab.research.google.com/): This is the simplest option. Nothing needs to be installed. All the coding is done through a web page.
#
# 2. NIH Cloud Lab: This option is good if you want to use cloud computing in your research. If you asked for an NIH Cloud Lab account, please look in your emails for an **email titled "Your Google Cloud Credits are Ready" for instructions**.
#
# 3. You can install Python locally on your computer. This option is best, e.g., if you are comfortable with installing software and plan to use large datasets available on your computer. There are various ways to set up a proper Python environment on your computer. If you need more information on how to proceed with such installation, please look for **an email titled "Software installation on personal computer"**.

# %% [markdown]
# ### Jupyter notebooks
#
# For the workshop, we will be using Jupyter notebooks. This document is an example of a Jupyter notebook. It constains both cells of text (like this one) in a format called "[markdown](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)" and cell of codes like the following one.

# %%
4+8
# Out:
# 12

# %%
# This is another code block, with no code (aside from this comment!)

# %% [markdown]
# ### A bit confused? Need more background information?
#
# - [3-minute introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI&ab_channel=TensorFlow)
# - [7-minute introduction to Jupyter Notebooks](https://www.youtube.com/watch?v=jZ952vChhuI&ab_channel=MichaelFudge)

# %% [markdown]
# # Second hour - Basic Python

# %% [markdown]
# Python is an excellent language for beginners. Here are some key characteristics:
#
# - **Easy to Use, Easy to Read, High-Level Language**: Python has a simple syntax that closely resembles English, making it easy to read and write. Its high-level nature means you can focus on what you want to achieve rather than how to do it.
#
# - **Interpreted and Dynamic**: Python is an interpreted language, which means you can run your code directly without a separate compilation step. This makes it easy to test and debug. It is also dynamic, so you do not need to declare variable types explicitly.
#
# - **Very Popular with Lots of Support**: Python's popularity means there is a vast amount of resources available. You can find numerous tutorials, forums, and libraries that can help you with almost any problem you encounter.

# %% [markdown]
# #### First line of code!

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Variables

# %% [markdown]
# ![Screenshot 2024-05-21 at 8.51.20 AM.png](data:image/png;base64,...)
#
#
# Modified from https://stevenpcurtis.medium.com/what-is-a-variable-3447ac1331b9

# %% [markdown]
# Each box has a name and the contents in it. For example, the box named 'num_cats' contains how many cats I have.
#
# Some restrictions on variable names:
# *   cannot have spaces
# *   cannot start with a number
# *   cannot be [reserved keyword](https://realpython.com/lessons/reserved-keywords/)

# %%
#the '=' is the assignment operator

my_var = 4

num_cat = 2.5

x = "hello"

# %% [markdown]
# All variables have a type. Basic types are: integers, floats, strings, booleans.
#
# Note: 5.0 is a float while 5 is and int and "5" or "5.0" is a string.

# %%
print(x)
print(type(x))

print(my_var)
print(type(my_var))

print(num_cat)
print(type(num_cat))
# Out:
# hello
# <class 'str'>
# 4
# <class 'int'>
# 2.5
# <class 'float'>

# %% [markdown]
# Different variable types behave differently:

# %%
print(my_var + 7)

small_num = 0.3
print(num_cat + small_num)

word = " World"
print(x + word)
# Out:
# 11
# 2.8
# hello World

# %%
# Will this work?
print(.067+5)
# Out:
# 5.067

# %%
# Will this work?
my_var = 4
print("Hello World" + my_var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4e117ddc7144> in <cell line: 3>()
#       1 # Will this work?
#       2 my_var = 4
# ----> 3 print("Hello World" + my_var)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# We need to "cast" my_var into a type compatible with "Hello World" for the
# operation "+". For example, we can just convert my_var from an int into a str.

my_var = str(4)
print("Hello World"+my_var)
# Out:
# Hello World4

# %%
# You can also assign this way.
a, b = 3, 5

print(a,' ', b)

a, b = b, a

print(a,' ',b)
# Out:
# 3   5
# 5   3

# %% [markdown]
# ## Operators

# %% [markdown]
# Python provides a variety of operators to perform different types of operations. We already kind of saw the '+' above but here are the most commonly used ones:

# %% [markdown]
# ### Arithmetic **Operators**

# %% [markdown]
# Arithmetic operators are used to perform basic mathematical operations.
#
# - **Addition (`+`)**: Adds two numbers.
#     ```python
#     x = 5
#     y = 3
#     result = x + y  # result is 8
#     ```
#
# - **Subtraction (`-`)**: Subtracts one number from another.
#     ```python
#     result = x - y  # result is 2
#     ```
#
# - **Multiplication (`*`)**: Multiplies two numbers.
#     ```python
#     result = x * y  # result is 15
#     ```
#
# - **Division (`/`)**: Divides one number by another, returning a float.
#     ```python
#     result = x / y  # result is 1.666...
#     ```
#
# - **Floor Division (`//`)**: Divides one number by another, returning an integer. **TRUCATES, or ROUNDS DOWN**
#     ```python
#     result = x // y  # result is 1
#     ```
#
# - **Modulus (`%`)**: Returns the remainder of a division.
#     ```python
#     result = x % y  # result is 2
#     ```
#
# - **Exponentiation (`**`)**: Raises one number to the power of another.
#     ```python
#     result = x ** y  # result is 125
#     ```

# %%
x=5
y=3

print(x*y/2)

print(x*y//2)

print(x ** y) #x at the power y, in our case 5*5*5
# Out:
# 7.5
# 7
# 125

# %% [markdown]
# ### Comparison Operators

# %% [markdown]
# Comparison operators are used to compare two values.
#
# - **Equal to (`==`)**: Checks if two values are equal.
#     ```python
#     x == y  # result is False
#     ```
#
# - **Not equal to (`!=`)**: Checks if two values are not equal.
#     ```python
#     x != y  # result is True
#     ```
#
# - **Greater than (`>`)**: Checks if the left value is greater than the right.
#     ```python
#     x > y  # result is True
#     ```
#
# - **Less than (`<`)**: Checks if the left value is less than the right.
#     ```python
#     x < y  # result is False
#     ```
#
# - **Greater than or equal to (`>=`)**: Checks if the left value is greater than or equal to the right.
#     ```python
#     x >= y  # result is True
#     ```
#
# - **Less than or equal to (`<=`)**: Checks if the left value is less than or equal to the right.
#     ```python
#     x <= y  # result is False
#     ```

# %%
print(x," ",y)
# Out:
# 5   3

# %%
print(x < y)
print(x == 5)
# Out:
# False
# True

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# still
# x = 5
# y = 3
#
#
# Logical operators are used to combine conditional statements.
#
# - **and**: Returns True if both statements are true.
#     ```python
#     (x > y) and (x < 10)  # result is True
#     ```
#
# - **or**: Returns True if one of the statements is true. **Note this is not XOR**
#     ```python
#     (x > y) or (x > 10)  # result is True
#     ```
#
# - **not**: Reverses the result, returns False if the result is true.
#     ```python
#     not (x > y)  # result is False
#     ```
#
# Note: The parentheses are not required here because of the [priority of operations](https://www.programiz.com/python-programming/precedence-associativity), but they do not hurt and can add to the clarity.

# %%
bool_one = x > y
print(bool_one)

bool_two = x < 10
print(bool_two)

print(bool_one and bool_two)
# Out:
# True
# True
# True

# %%
print(bool_one and (x < 4))  # False
print(bool_one or (x < 4))   # True
# Out:
# False
# True

# %%
var_with_bool = bool_one or (x < 4)
print(not(var_with_bool)) # not True
# Out:
# False

# %% [markdown]
# ## Basic Data Structures

# %% [markdown]
# Python offers several built-in data structures essential for organizing and managing data. The most commonly used ones are lists and dictionaries. These are similar to variables in that they store a piece of information (e.g., a number) but can now store many things rather than just one thing. You can think not a box with one thing in it (variable) but a container full of boxes (a data structure).

# %% [markdown]
# ### Lists

# %% [markdown]
# A list is an ordered, mutable collection of items. Lists are versatile and can hold items of different data types.
#
# Note: Since it is mutable we can change and modify it after creating.
#
# - **Creating a list**: Lists are created using square brackets `[]`.
#     ```python
#     fruits = ["apple", "banana", "cherry"]
#     ```
#
# - **Accessing Elements**: Access elements by their index **(starting from 0)**.
#     ```python
#     print(fruits[0])  # Output: apple
#     ```
#
# - **Modifying Elements**: Change the value of a specific element.
#     ```python
#     fruits[1] = "blueberry"  # Overwrite "banana" with blueberry
#     ```
#
# - **Adding Elements**: Use `append()` to add an element to the end of the list.
#     ```python
#     fruits.append("date")
#     ```
#
# - **Removing Elements by Value**: Use `remove()` to remove a specific element with that value.
#     ```python
#     fruits.remove("apple")
#     ```
#
# - **Removing Elements by Index**: Use `pop()` to remove a specific element at a specific index.
#     ```python
#     fruits.pop(0)  # Removes the first item of the list.
#     ```

# %%
my_list = []

print(my_list)
# Out:
# []

# %%
my_list.append("luci")
print(my_list,'\n')

my_list.append("marry")
print(my_list,'\n')

#you can add a to a list
my_list.append(["bob","tom"])
print(my_list)
# Out:
# ['luci']
#
# ['luci', 'marry']
#
# ['luci', 'marry', ['bob', 'tom']]

# %%
# But most of the time, your probably want to "extend" the list by another list...
my_list.remove(["bob","tom"])
print(my_list)
my_list.extend(["bob","tom"])
print(my_list)
# Out:
# ['luci', 'marry']
# ['luci', 'marry', 'bob', 'tom']

# %%
#getting the last element
last_elem = my_list[-1]
print(last_elem)
# Out:
# tom

# %%
my_list[0] = 1801
print(my_list,'\n')
# Out:
# [1801, 'marry', 'bob', 'tom']

# %%
my_list.remove('marry')
print(my_list)
# Out:
# [1801, 'bob', 'tom']

# %%
my_list.pop(0)
print(my_list)
# Out:
# ['bob', 'tom']

# %%
# The + operator can be used to concatenate two lists
my_list + ["some", "more", "stuff"]
# Out:
# ['bob', 'tom', 'some', 'more', 'stuff']

# %% [markdown]
# Note: We did not use print here! In Jupyter notebook, whatever is "returned" by the last instructions of a cell is automatically printed...

# %%
x = my_list + ["some", "more", "stuff"]
print(x)
# Out:
# ['bob', 'tom', 'some', 'more', 'stuff']

# %% [markdown]
# ### Dictionary (a.k.a. the reason why Python is so great)

# %% [markdown]
# A dictionary is an unordered, mutable collection of key-value pairs. Each key must be unique.
#
# - **Creating a Dictionary**: Dictionaries are created using curly braces `{}`, separating keys and values by ":" (i.e., key: value).
#     ```python
#     person = {"name": "John", "age": 30, "city": "New York"}
#     ```
#
# - **Accessing Elements**: Access values by their keys.
#     ```python
#     print(person["name"])  # Output: John
#     ```
#
# - **Modifying Elements**: Change the value associated with a specific key.
#     ```python
#     person["age"] = 31
#     ```
#
# - **Adding Elements**: Add a new key-value pair.
#     ```python
#     person["job"] = "Engineer"
#     ```
#
# - **Removing Elements**: Use `del` to remove a key-value pair.
#     ```python
#     del person["city"]
#     ```

# %%
people_colors = {
    "Alice": "blue",
    "Bob": "green",
    "Charlie": "red",
    "Kuba": "Not orange",
    "Cocky": "Garnet"
}

print(people_colors)
# Out:
# {'Alice': 'blue', 'Bob': 'green', 'Charlie': 'red', 'Kuba': 'Not orange', 'Cocky': 'Garnet'}

# %%
print('Favorite color of Cocky is:', people_colors["Cocky"])
# Out:
# Favorite color of Cocky is: Garnet

# %% [markdown]
# ## The ```len()``` Function

# %% [markdown]
# The function `len()` works on all builtin Python data structures. This function takes as an argument the data structure and returns the length of the data structure.

# %%
print(my_list, len(my_list))
print(people_colors, len(people_colors))
# Out:
# ['bob', 'tom'] 2
# {'Alice': 'blue', 'Bob': 'green', 'Charlie': 'red', 'Kuba': 'Not orange', 'Cocky': 'Garnet'} 5

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Variables
#
# **Basic Variable Assignment**:
#
#
# 1.   Assign the value `10` to a variable named `a`.
# 2.   Assign the value `20` to a variable named `b`.
# 3.   Print the values of `a` and `b`.

# %%
a = 10
b = 20
print(a, b)
# Out:
# 10 20

# %% [markdown]
# **Swapping Variables**:
# 1.   Swap the values of `a` and `b` without using a temporary variable.
# 2.   Print the values of `a` and `b` after swapping.

# %%
a, b = b, a
print(a, b)
# Out:
# 20 10

# %% [markdown]
# ### List
# **Favorite Dishes List**:
#
#
# 1.   Create a variable named `dishes` and use it to store a list of your 5 favorite dishes, in order of preference. Print this variable.

# %%
dishes = ["shish taouk", "pizza", "lasagna", "tonkinese soup", "stroganoff beef"]
print(dishes)
# Out:
# ['shish taouk', 'pizza', 'lasagna', 'tonkinese soup', 'stroganoff beef']

# %% [markdown]
# **Favorite Dishes Sentence**:
# 1.   Using the data stored in the variable `dishes`, print a sentence that tells what is your first and fifth favorite dish (e.g., the printed output could look like this: "shish taouk is my favorite dish and stroganoff beef is my fifth favorite dish.")

# %%
print(dishes[0], "is my favorite dish and", dishes[4], "is my fifth favorite dish.")
# Out:
# shish taouk is my favorite dish and stroganoff beef is my fifth favorite dish.

# %% [markdown]
# ### Dictionary
# **Dictionary Operations**:
#
#
# 1.   Create a dictionary with keys "name", "age", and "city" with corresponding values "Alice", 25, and "New York".
# 2.   Add a new key "job" with the value "Engineer".
# 3.   Remove the key "age".
# 4.   Print the final dictionary.

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
person["job"] = "Engineer"
del person["age"]
print(person)
# Out:
# {'name': 'Alice', 'city': 'New York', 'job': 'Engineer'}

# %% [markdown]
# **Menu Dictionary**:
#
#
# 1.  Using the data stored in the variable `dishes`, create a new variable `menu` which maps the days of the week (keys) with the dishes that you will eat (values) such that you eat your favorite meal on Monday, your second favorite meal on Tuesday, and so on.
# 2. Print the variable `menu`.

# %%
menu = {"monday": dishes[0],
            "tuesday": dishes[1],
            "wednesday": dishes[2],
            "thursday": dishes[3],
            "friday":  dishes[4]}
print(menu)
# Out:
# {'monday': 'shish taouk', 'tuesday': 'pizza', 'wednesday': 'lasagna', 'thursday': 'tonkinese soup', 'friday': 'stroganoff beef'}

# %% [markdown]
# **Add to Dictionary**:
#
# 1.       Add two new entries to your `menu` dictionary for Saturday and Sunday
# 2.   Create a string that states how many dishes are on the menu. Use the `len()` function for this (e.g., the printed string could look like this "There are 7 dishes on the menu").
# 3. Print that  string

# %%
    menu["saturday"] = "burger"
    menu["sunday"] = "risotto"
    ans = "There are "+str(len(menu))+" dishes on the menu"
    print(ans)
# Out:
# There are 7 dishes on the menu

# %% [markdown]
# 1.   Create a dictionary variable where the keys are the variable name (dishes and menu) and values are dictionaries.  These "inner" dictionaries will have two keys: type,  and content. The corresponding values should be the variable type (i.e., type(my_variable)) and the content of the variable.
#
# 2.   Print variables.
#
#
# It should look something like this (but all on one line).
#
# ```
# {'dishes': {'type': <class 'list'>,
#             'content': ['shish taouk', 'pizza', 'lazagna',
#                         'spagetti', 'stroganoff beaf']
#             },
#  'menu': {'type': <class 'dict'>,
#           'content': {'Monday': 'shish taouk', 'Tuesday': 'pizza',
#                       'Wednesday': 'burger', 'Thursday': 'spagetti',
#                       'Friday': 'stroganoff beaf', 'Saturday': 'hot dog'}
#           }
# }
# ```

# %%
variable = {"menu": {"type": type(menu), "content": menu},
            "dishes": {"type": type(dishes), "content": dishes}}
print(variable)
# Out:
# {'menu': {'type': <class 'dict'>, 'content': {'monday': 'shish taouk', 'tuesday': 'pizza', 'wednesday': 'lasagna', 'thursday': 'tonkinese soup', 'friday': 'stroganoff beef', 'saturday': 'burger', 'sunday': 'risotto'}}, 'dishes': {'type': <class 'list'>, 'content': ['shish taouk', 'pizza', 'lasagna', 'tonkinese soup', 'stroganoff beef']}}

# %% [markdown]
# ### **Additional resources**
#
# - [link to Geeks for Geeks python intro](https://www.geeksforgeeks.org/introduction-to-python/)
# - Video tutorials
#     - [Python variables and data types you should know about as a beginner](https://www.youtube.com/watch?v=LKFrQXaoSMQ)
#     - [Lists, Tuples, and Sets](https://www.youtube.com/watch?v=W8KRzm-HUcc)
#     - [Dictionaries](https://www.youtube.com/watch?v=daefaLgNkw0)
# - Tutorial with exercise:
#     - [Python Variables](https://www.w3schools.com/python/python_variables.asp)
#     - [Python Lists](https://www.w3schools.com/python/python_lists.asp)
#     - [Python Dictionaries](https://www.w3schools.com/python/python_dictionaries.asp)
# - Additionak exercise:
#     - [Lists](https://www.w3resource.com/python-exercises/list/)
#     - [Dictionaries](https://www.w3resource.com/python-exercises/dictionary/)

# %% [markdown]
# # Extra material

# %% [markdown]
# ### Tuple

# %% [markdown]
# A tuple is an ordered, immutable collection of items. Once created, the elements of a tuple cannot be changed. A great way to think of an Tuple is like an immutable list (can't be changed after creation).
#
# - **Creating a Tuple**: Tuples are created using parentheses `()`.
#     ```python
#     dimensions = (1920, 1080)
#     ```
#
# - **Accessing Elements**: Access elements by their index.
#     ```python
#     print(dimensions[0])  # Output: 1920
#     ```
#
# - **Immutability**: You cannot modify elements of a tuple.
#     ```python
#     # This will raise an error
#     # dimensions[0] = 1280
#     ```

# %%
#Tuple unpacking
dimensions = (1920,1080)
x_dim, y_dim = dimensions
print(x_dim,' ',y_dim)
# Out:
# 1920   1080

# %% [markdown]
# ### Set

# %% [markdown]
# A set is an unordered collection of unique items. Sets are useful for membership testing and eliminating duplicate entries. Just like a set in mathimatics.
#
# - **Creating a Set**: Sets are created using curly braces `{}` or the `set()` function.
#     ```python
#     colors = {"red", "green", "blue"}
#     ```
#
# - **Adding Elements**: Use `add()` to add an element to the set.
#     ```python
#     colors.add("yellow")
#     ```
#
# - **Removing Elements**: Use `remove()` to remove a specific element.
#     ```python
#     colors.remove("green")
#     ```
#
# - **Set Operations**: Perform operations like union, intersection, and difference.
#     ```python
#     set1 = {1, 2, 3}
#     set2 = {3, 4, 5}
#
#     union_set = set1.union(set2)  # {1, 2, 3, 4, 5}
#     intersection_set = set1.intersection(set2)  # {3}
#     difference_set = set1.difference(set2)  # {1, 2}
#     ```

# %%
set00 = {2,8,90}
print(len(set00))
# Out:
# 3

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Tuple Operations**:
#
#
# 1.   Create a tuple with the values `(1, 2, 3, 4, 5)`.
# 2.   Print the first element and the last element of the tuple.

# %%
t = (1, 2, 3, 4, 5)
print(t[0], t[-1])
# Out:
# 1 5

# %% [markdown]
# **Tuple Unpacking**:
# 1.   Unpack the tuple `(a, b, c, d, e)` into three variables and print them.

# %%
a, b, c, d, e = t
print(a, b, c, d, e)
# Out:
# 1 2 3 4 5

# %% [markdown]
# **Set Operations**:
#
#
# 1.   Create a set with the values `{1, 2, 3, 4, 5}`.
# 2.   Add the value `6` to the set.
# 3.   Remove the value `3` from the set.
# 4.   Print the final set.

# %%
numbers_set = {1, 2, 3, 4, 5}
numbers_set.add(6)
numbers_set.remove(3)
print(numbers_set)
# Out:
# {1, 2, 4, 5, 6}

# %% [markdown]
# **Set Operations (Continued)**:
#
#
# 1.   Create another set with values `{4, 5, 6, 7, 8}`.
# 2.   Compute and print the union, intersection, and difference of the two sets.

# %%
set2 = {4, 5, 6, 7, 8}
print(numbers_set.union(set2))
print(numbers_set.intersection(set2))
print('Whats in set numbers_set and not in set set2:',numbers_set.difference(set2))
print('Whats in set set2 and not in set numbers_set:',set2.difference(numbers_set))
